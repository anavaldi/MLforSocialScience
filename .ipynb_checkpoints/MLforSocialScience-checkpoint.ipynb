# %% [markdown]
# # Machine Learning for Social Science

# %% [markdown]
# ### 1. Doing some basic descriptive statistics

# %% [markdown]
# Loading packages for reading datasets

# %% [markdown]
# If you would rather to work on a similar analysis on R, go to: https://github.com/propublica/compas-analysis/blob/master/Compas%20Analysis.ipynb

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# First, we read the dataset

# %%
dataset = pd.read_csv('propublica_violent_recidivism.csv')

# %% [markdown]
# Take a look to the dataset

# %%
dataset.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race      ...        \
# 0  1947-04-18   69  Greater than 45             Other      ...
# 1  1982-01-22   34          25 - 45  African-American      ...
# 2  1991-05-14   24     Less than 25  African-American      ...
# 3  1993-01-21   23     Less than 25  African-American      ...
# 4  1973-01-22   43          25 - 45             Other      ...
#
#    v_decile_score  v_score_text  v_screening_date  in_custody  out_custody  \
# 0               1           Low        2013-08-14  2014-07-07   2014-07-14
# 1               1           Low        2013-01-27  2013-01-26   2013-02-05
# 2               3           Low        2013-04-14  2013-06-16   2013-06-16
# 3               6        Medium        2013-01-13         NaN          NaN
# 4               1           Low        2013-03-26         NaN          NaN
#
#    priors_count.1 start   end event two_year_recid
# 0               0     0   327     0              0
# 1               0     9   159     1              1
# 2               4     0    63     0              1
# 3               1     0  1174     0              0
# 4               2     0  1102     0              0
#
# [5 rows x 53 columns]

# %% [markdown]
# Which variables do we have?

# %%
list(dataset.columns.values)
# Out:
# ['id',
#  'name',
#  'first',
#  'last',
#  'compas_screening_date',
#  'sex',
#  'dob',
#  'age',
#  'age_cat',
#  'race',
#  'juv_fel_count',
#  'decile_score',
#  'juv_misd_count',
#  'juv_other_count',
#  'priors_count',
#  'days_b_screening_arrest',
#  'c_jail_in',
#  'c_jail_out',
#  'c_case_number',
#  'c_offense_date',
#  'c_arrest_date',
#  'c_days_from_compas',
#  'c_charge_degree',
#  'c_charge_desc',
#  'is_recid',
#  'r_case_number',
#  'r_charge_degree',
#  'r_days_from_arrest',
#  'r_offense_date',
#  'r_charge_desc',
#  'r_jail_in',
#  'r_jail_out',
#  'violent_recid',
#  'is_violent_recid',
#  'vr_case_number',
#  'vr_charge_degree',
#  'vr_offense_date',
#  'vr_charge_desc',
#  'type_of_assessment',
#  'decile_score.1',
#  'score_text',
#  'screening_date',
#  'v_type_of_assessment',
#  'v_decile_score',
#  'v_score_text',
#  'v_screening_date',
#  'in_custody',
#  'out_custody',
#  'priors_count.1',
#  'start',
#  'end',
#  'event',
#  'two_year_recid',
#  'two_year_recid.1']

# %% [markdown]
# Let's take a look to age, gender, and race distribution

# %%
print(dataset.age.describe())
# Out:
# count    7214.000000
# mean       34.817993
# std        11.888922
# min        18.000000
# 25%        25.000000
# 50%        31.000000
# 75%        42.000000
# max        96.000000
# Name: age, dtype: float64

# %%
print(dataset['sex'].value_counts())
# Out:
# Male      5819
# Female    1395
# Name: sex, dtype: int64

# %%
print(dataset['race'].value_counts())
# Out:
# African-American    3696
# Caucasian           2454
# Hispanic             637
# Other                377
# Asian                 32
# Native American       18
# Name: race, dtype: int64

# %%
print(dataset.groupby('race').age.describe())
# Out:
#                    count       mean        std   min    25%   50%    75%   max
# race
# African-American  3696.0  32.740801  10.858391  18.0  25.00  30.0  38.00  77.0
# Asian               32.0  37.781250  13.212248  20.0  27.50  35.5  46.25  76.0
# Caucasian         2454.0  37.726569  12.761373  18.0  27.00  35.0  47.75  83.0
# Hispanic           637.0  35.455259  11.877783  19.0  26.00  33.0  43.00  96.0
# Native American     18.0  32.888889   8.676465  20.0  26.25  33.0  39.50  47.0
# Other              377.0  35.013263  11.606232  19.0  25.00  32.0  43.00  70.0

# %% [markdown]
# Let's now study the distribution of the score text.

# %%
print(dataset['score_text'].value_counts())
# Out:
# Low       3897
# Medium    1914
# High      1403
# Name: score_text, dtype: int64

# %% [markdown]
# Cross tabs are fun!

# %%
ctab_race_scoretext = pd.crosstab(dataset.race, dataset.score_text, margins=True)
print(ctab_race_scoretext)
# Out:
# score_text        High   Low  Medium   All
# race
# African-American  1025  1522    1149  3696
# Asian                3    24       5    32
# Caucasian          276  1600     578  2454
# Hispanic            67   447     123   637
# Native American      6     6       6    18
# Other               26   298      53   377
# All               1403  3897    1914  7214

# %% [markdown]
# ### 2. Analyzing the bias in COMPAS

# %% [markdown]
# Is there any bias? Let's plot!

# %%
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

# %%
dataset['decile_score'] = dataset['decile_score'].astype('category')

# %%
ggplot(dataset.loc[dataset['race'] == 'African-American' ]) + aes(x='decile_score') + geom_bar(size=20) + geom_bar() + xlab("Decile Score") + ylim(0, 650) + ggtitle("Black Defendant's Decile Scores")
# Out:
# <ggplot: (8734150159585)>

# %%
ggplot(dataset.loc[dataset['race'] == 'Caucasian' ]) + aes(x='decile_score') + geom_bar() + xlab("Decile Score") + ylim(0, 650) + ggtitle("White's Decile Scores")
# Out:
# <ggplot: (8734154306708)>

# %% [markdown]
# ### 3. Building your first ML model

# %% [markdown]
# The first model we are going to build is a Decision Tree.

# %% [markdown]
# But... What is a Decision Tree?

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2016/04/complete-tutorial-tree-based-modeling-scratch-in-python/

# %% [markdown]
# We first load the required packages.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# We need to transfrom categorical variables into numbers.

# %%
dataset['sex_num'] = np.where(dataset['sex'] == 'Male', 0, 1)

# %% [markdown]
# We need to split the dataset intro train and test to avoid overfitting.

# %%
X = dataset[['age', 'sex_num', 'priors_count', 'is_recid']]
y = dataset[['two_year_recid']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 15, test_size = 0.25)

# %% [markdown]
# We need to also transform missing values

# %%
c = X_train.select_dtypes(np.number).columns
X_train[c] = X_train[c].fillna(0)
X_train = X_train.fillna("")

y_train = np.where(y_train == 0, 0, 1)

# %% [markdown]
# Make the same for test...

# %%
# Code here

# %% [markdown]
# And then, we build the classifier. But let's take a look first to the Python's documentation.

# %% [markdown]
# https://scikit-learn.org/stable/modules/tree.html

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %% [markdown]
# Let's observe the tree...

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("train") 

dot_data = tree.export_graphviz(clf, out_file=None, feature_names = ['age', 'sex_num', 'priors_count', 'is_recid'], class_names = ['no_reof', 'reof'], filled=True, rounded=True, special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
